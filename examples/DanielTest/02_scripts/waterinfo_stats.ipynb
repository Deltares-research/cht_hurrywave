# %%
import os
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from matplotlib import animation
from mpl_toolkits.basemap import Basemap
import contextily as cx  
import xarray as xr
from matplotlib.colors import TwoSlopeNorm
from matplotlib.colors import LinearSegmentedColormap
from scipy.spatial import cKDTree
from datetime import datetime
from matplotlib import gridspec
import scipy.stats as stats
import wavespectra
import netCDF4 as nc
import h5py
import numbers
import copy
from statsmodels.tsa.stattools import acf
from statsmodels.stats.diagnostic import acorr_ljungbox
import pymannkendall as mk
import calendar
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import RANSACRegressor
import re
from scipy.stats import norm


#import 
# %matplotlib inline

# %%
base_path = "/gpfs/work3/0/ai4nbs/hurry_wave/north_sea"
output_dir = os.path.join(base_path, "04_modelruns" , "YearSims", "01_postprocess", "plots","test")
if not os.path.exists(output_dir):
    os.makedirs(output_dir)

# parser = argparse.ArgumentParser(description="Postprocess Hurrywave output.")
# parser.add_argument("--model_name", type=str, required=True, help="Name of the model run")
# parser.add_argument("--data_name", type=str, required=True, help="Name of the data set")
# args = parser.parse_args()

# model_name = args.model_name
# data_name = args.data_name

year_start = 2023 # Latest year
year_end = 1950 # Earliest year

month_start = 12 # Latest month
month_end = 1 # Earliest month

day_start = 31 # Latest day
day_end = 1 # Earliest day

hour_start = 23 # Latest hour
hour_end = 0 # Earliest hour

years  = np.arange(year_start, year_end - 1, -1)
months = np.arange(month_start, month_end - 1, -1)
days   = np.arange(day_start, day_end - 1, -1)
hours  = np.arange(hour_start, hour_end - 1, -1)

run_tests = True

area = [65, -12, 48, 10] # DCSM area in the North Sea (degrees): North, West, South, East

# model_path = os.path.join(base_path, '04_modelruns', 'YearSims',model_name)
 
model_path = os.path.join(base_path, '04_modelruns', 'YearSims')
model_path_start = os.path.join(model_path, str(year_start)) 
postprocess_path = os.path.join(base_path, '05_postprocessing', 'his_files_per_station')
spectral_data_path = os.path.join(base_path, '01_data', 'spectral_buoy_data')
ERA5_data_path = '/gpfs/work3/0/ai4nbs/ERA5_data/data'


inp_file = os.path.join(model_path_start, 'hurrywave.inp')
tstart = f"{year_end}{month_end}{day_end} {hour_end}0000" # earliest time
tstop = f"{year_start}{month_start}{day_start} {hour_start}0000" # latest time

# DCSM bounding box: [North, West, South, East]
area = area  # (N, W, S, E)

# Find the start and stop times from the input file
with open(inp_file, 'r') as f:
    for line in f:
        if line.strip().startswith('tspinup'):
            tspinup = line.split('=')[1].strip()


# Ensure time is in "yyyymmdd hhmmss" format
def parse_time(s):
    parts = s.strip().split()
    if len(parts) == 2:
        date, time = parts
    elif len(parts) == 1:
        date = parts[0][:8]
        time = parts[0][8:] if len(parts[0]) > 8 else "000000"
    else:
        date, time = "00000000", "000000"  # fallback
    return f"{date} {time}"


tstart_str = parse_time(tstart)
tstop_str = parse_time(tstop)

tstart_dt = datetime.strptime(tstart_str, "%Y%m%d %H%M%S")
tstop_dt = datetime.strptime(tstop_str, "%Y%m%d %H%M%S")

# %%
# Path to Waterinfo_RWS data
waterinfo_base = os.path.join(base_path, "01_data", "Waterinfo_RWS")

# Collect all years available in Waterinfo_RWS
obs_years = sorted([d for d in os.listdir(waterinfo_base) if d.isdigit()])
# Only keep years from year_start down to year_end (inclusive)
obs_years = [year for year in obs_years if int(year) <= year_start and int(year) >= year_end]
obs_years = sorted(obs_years, reverse=True)  # Descending order: year_start to year_end

print(obs_years)
# Dictionary to hold all observational data per station
obs_data_per_station = {}

for year in obs_years:
    print(f"Loading observational data for year: {year}")
    year_dir = os.path.join(waterinfo_base, year)
    for fname in os.listdir(year_dir):
        if fname.endswith('.csv'):
            station = fname.replace('.csv', '')
            fpath = os.path.join(year_dir, fname)
            if not os.path.exists(fpath):
                print(f"File not found: {fpath}, skipping.")
                continue

            # Check if file is empty or contains no columns
            with open(fpath, 'r') as checkfile:
                first_line = checkfile.readline()
                if not first_line or len(first_line.strip().split(',')) < 2:
                    print(f"File {fpath} contains no columns, skipping.")
                    continue
            df = pd.read_csv(fpath, parse_dates=True)
            if df.empty:
                print(f"Skipping {fpath} as it contains no data records.")
                continue  # Skip file if no data record
            if df.empty or len(df) < 10:
                print(f"Skipping {fpath} as it contains no data records or less than 10 records.")
                continue  # Skip file if no data record or too few records
            df['year'] = int(year)
            if station not in obs_data_per_station:
                obs_data_per_station[station] = [df]
            else:
                obs_data_per_station[station].append(df)

    print(f"Finished loading observational data from Waterinfo_RWS for {len(obs_data_per_station)} stations.")

# Concatenate yearly dataframes for each station
for station in obs_data_per_station:
    obs_data_per_station[station] = pd.concat(obs_data_per_station[station], ignore_index=True)
    #divide all values of hm0 by 100 as they are in cm
    if 'hm0' in obs_data_per_station[station]:
        obs_data_per_station[station]['hm0'] = obs_data_per_station[station]['hm0'] / 100

    # t13 is divided by 0.95 to move to Tp
    if 't13' in obs_data_per_station[station]:
        obs_data_per_station[station]['t13'] = obs_data_per_station[station]['t13'] / 0.95

    # If the dataframe has
    # 'Unnamed: 0' as a column, rename it to 'time'
    for station in obs_data_per_station:
        if isinstance(obs_data_per_station[station], pd.DataFrame):
            if 'Unnamed: 0' in obs_data_per_station[station]:
                # Convert to pandas datetime first, then to numpy.datetime64 array
                print(station)
                time_pd = pd.to_datetime(obs_data_per_station[station].pop('Unnamed: 0'))
                obs_data_per_station[station]['time'] = time_pd.values.astype('datetime64[ns]')
# Out:
# ['2023', '2022', '2021', '2020', '2019', '2018', '2017', '2016', '2015', '2014', '2013', '2012', '2011', '2010', '2009', '2008', '2007', '2006', '2005', '2004', '2003', '2002', '2001', '2000', '1999', '1998', '1997', '1996', '1995', '1994', '1993', '1992', '1991', '1990', '1989', '1988', '1987', '1986', '1985', '1984', '1983', '1982', '1981', '1980', '1979', '1978', '1977', '1976', '1975', '1974', '1973', '1972', '1971', '1970', '1969', '1968', '1967', '1966', '1965', '1964', '1963', '1962', '1961', '1960', '1959', '1958', '1957', '1956', '1955', '1954', '1953', '1952', '1951', '1950']
# Loading observational data for year: 2023
# Skipping /gpfs/work3/0/ai4nbs/hurry_wave/north_sea/01_data/Waterinfo_RWS/2023/Platform Hoorn Q1-A.csv as it contains no data records or less than 10 records.
# Skipping /gpfs/work3/0/ai4nbs/hurry_wave/north_sea/01_data/Waterinfo_RWS/2023/Platform F16-A.csv as it contains no data records or less than 10 records.
# Finished loading observational data from Waterinfo_RWS for 6 stations.
# Loading observational data for year: 2022
# Skipping /gpfs/work3/0/ai4nbs/hurry_wave/north_sea/01_data/Waterinfo_RWS/2022/Platform F16-A.csv as it contains no data records or less than 10 records.
# Skipping /gpfs/work3/0/ai4nbs/hurry_wave/north_sea/01_data/Waterinfo_RWS/2022/K13 Alpha.csv as it contains no data records or less than 10 records.
# Finished loading observational data from Waterinfo_RWS for 7 stations.
# Loading observational data for year: 2021
# Skipping /gpfs/work3/0/ai4nbs/hurry_wave/north_sea/01_data/Waterinfo_RWS/2021/Platform F16-A.csv as it contains no data records or less than 10 records.
# Skipping /gpfs/work3/0/ai4nbs/hurry_wave/north_sea/01_data/Waterinfo_RWS/2021/K13 Alpha.csv as it contains no data records or less than 10 records.
# Finished loading observational data from Waterinfo_RWS for 7 stations.
# Loading observational data for year: 2020
# Skipping /gpfs/work3/0/ai4nbs/hurry_wave/north_sea/01_data/Waterinfo_RWS/2020/K13 Alpha.csv as it contains no data records or less than 10 records.
# Finished loading observational data from Waterinfo_RWS for 8 stations.
# Loading observational data for year: 2019
# Skipping /gpfs/work3/0/ai4nbs/hurry_wave/north_sea/01_data/Waterinfo_RWS/2019/K13 Alpha.csv as it contains no data records or less than 10 records.
# Finished loading observational data from Waterinfo_RWS for 8 stations.
# Loading observational data for year: 2018
# Skipping /gpfs/work3/0/ai4nbs/hurry_wave/north_sea/01_data/Waterinfo_RWS/2018/K13 Alpha.csv as it contains no data records or less than 10 records.
# Finished loading observational data from Waterinfo_RWS for 8 stations.
# Loading observational data for year: 2017
# Skipping /gpfs/work3/0/ai4nbs/hurry_wave/north_sea/01_data/Waterinfo_RWS/2017/K13 Alpha.csv as it contains no data records or less than 10 records.
# Finished loading observational data from Waterinfo_RWS for 8 stations.
# Loading observational data for year: 2016
# Skipping /gpfs/work3/0/ai4nbs/hurry_wave/north_sea/01_data/Waterinfo_RWS/2016/K13 Alpha.csv as it contains no data records or less than 10 records.
# Finished loading observational data from Waterinfo_RWS for 8 stations.
# Loading observational data for year: 2015
# Skipping /gpfs/work3/0/ai4nbs/hurry_wave/north_sea/01_data/Waterinfo_RWS/2015/K13 Alpha.csv as it contains no data records or less than 10 records.
# Finished loading observational data from Waterinfo_RWS for 8 stations.
# Loading observational data for year: 2014
# Skipping /gpfs/work3/0/ai4nbs/hurry_wave/north_sea/01_data/Waterinfo_RWS/2014/K13 Alpha.csv as it contains no data records or less than 10 records.
# Finished loading observational data from Waterinfo_RWS for 8 stations.
# Loading observational data for year: 2013
# Skipping /gpfs/work3/0/ai4nbs/hurry_wave/north_sea/01_data/Waterinfo_RWS/2013/K13 Alpha.csv as it contains no data records or less than 10 records.
# Finished loading observational data from Waterinfo_RWS for 8 stations.
# Loading observational data for year: 2012
# Skipping /gpfs/work3/0/ai4nbs/hurry_wave/north_sea/01_data/Waterinfo_RWS/2012/K13 Alpha.csv as it contains no data records or less than 10 records.
# Finished loading observational data from Waterinfo_RWS for 8 stations.
# Loading observational data for year: 2011
# Skipping /gpfs/work3/0/ai4nbs/hurry_wave/north_sea/01_data/Waterinfo_RWS/2011/K13 Alpha.csv as it contains no data records or less than 10 records.
# Finished loading observational data from Waterinfo_RWS for 8 stations.
# Loading observational data for year: 2010
# Skipping /gpfs/work3/0/ai4nbs/hurry_wave/north_sea/01_data/Waterinfo_RWS/2010/K13 Alpha.csv as it contains no data records or less than 10 records.
# Finished loading observational data from Waterinfo_RWS for 8 stations.
# Loading observational data for year: 2009
# Skipping /gpfs/work3/0/ai4nbs/hurry_wave/north_sea/01_data/Waterinfo_RWS/2009/K13 Alpha.csv as it contains no data records or less than 10 records.
# Finished loading observational data from Waterinfo_RWS for 8 stations.
# Loading observational data for year: 2008
# Skipping /gpfs/work3/0/ai4nbs/hurry_wave/north_sea/01_data/Waterinfo_RWS/2008/Platform Hoorn Q1-A.csv as it contains no data records or less than 10 records.
# Skipping /gpfs/work3/0/ai4nbs/hurry_wave/north_sea/01_data/Waterinfo_RWS/2008/Platform F16-A.csv as it contains no data records or less than 10 records.
# Skipping /gpfs/work3/0/ai4nbs/hurry_wave/north_sea/01_data/Waterinfo_RWS/2008/Platform D15-A.csv as it contains no data records or less than 10 records.
# Skipping /gpfs/work3/0/ai4nbs/hurry_wave/north_sea/01_data/Waterinfo_RWS/2008/K13 Alpha.csv as it contains no data records or less than 10 records.
# Skipping /gpfs/work3/0/ai4nbs/hurry_wave/north_sea/01_data/Waterinfo_RWS/2008/North Cormorant.csv as it contains no data records or less than 10 records.
# Finished loading observational data from Waterinfo_RWS for 8 stations.
# Loading observational data for year: 2007
# Skipping /gpfs/work3/0/ai4nbs/hurry_wave/north_sea/01_data/Waterinfo_RWS/2007/Platform Hoorn Q1-A.csv as it contains no data records or less than 10 records.
# Skipping /gpfs/work3/0/ai4nbs/hurry_wave/north_sea/01_data/Waterinfo_RWS/2007/Platform F16-A.csv as it contains no data records or less than 10 records.
# Skipping /gpfs/work3/0/ai4nbs/hurry_wave/north_sea/01_data/Waterinfo_RWS/2007/Platform D15-A.csv as it contains no data records or less than 10 records.
# Skipping /gpfs/work3/0/ai4nbs/hurry_wave/north_sea/01_data/Waterinfo_RWS/2007/K13 Alpha.csv as it contains no data records or less than 10 records.
# Skipping /gpfs/work3/0/ai4nbs/hurry_wave/north_sea/01_data/Waterinfo_RWS/2007/North Cormorant.csv as it contains no data records or less than 10 records.
# Finished loading observational data from Waterinfo_RWS for 8 stations.
# Loading observational data for year: 2006
# Skipping /gpfs/work3/0/ai4nbs/hurry_wave/north_sea/01_data/Waterinfo_RWS/2006/Platform Hoorn Q1-A.csv as it contains no data records or less than 10 records.
# Skipping /gpfs/work3/0/ai4nbs/hurry_wave/north_sea/01_data/Waterinfo_RWS/2006/Platform F16-A.csv as it contains no data records or less than 10 records.
# Skipping /gpfs/work3/0/ai4nbs/hurry_wave/north_sea/01_data/Waterinfo_RWS/2006/Platform D15-A.csv as it contains no data records or less than 10 records.
# Skipping /gpfs/work3/0/ai4nbs/hurry_wave/north_sea/01_data/Waterinfo_RWS/2006/K13 Alpha.csv as it contains no data records or less than 10 records.
# Finished loading observational data from Waterinfo_RWS for 8 stations.
# Loading observational data for year: 2005
# Skipping /gpfs/work3/0/ai4nbs/hurry_wave/north_sea/01_data/Waterinfo_RWS/2005/Platform Hoorn Q1-A.csv as it contains no data records or less than 10 records.
# Skipping /gpfs/work3/0/ai4nbs/hurry_wave/north_sea/01_data/Waterinfo_RWS/2005/Platform F16-A.csv as it contains no data records or less than 10 records.
# Skipping /gpfs/work3/0/ai4nbs/hurry_wave/north_sea/01_data/Waterinfo_RWS/2005/Platform D15-A.csv as it contains no data records or less than 10 records.
# Skipping /gpfs/work3/0/ai4nbs/hurry_wave/north_sea/01_data/Waterinfo_RWS/2005/K13 Alpha.csv as it contains no data records or less than 10 records.
# Finished loading observational data from Waterinfo_RWS for 8 stations.
# Loading observational data for year: 2004
# Skipping /gpfs/work3/0/ai4nbs/hurry_wave/north_sea/01_data/Waterinfo_RWS/2004/Platform Hoorn Q1-A.csv as it contains no data records or less than 10 records.
# Skipping /gpfs/work3/0/ai4nbs/hurry_wave/north_sea/01_data/Waterinfo_RWS/2004/Platform F16-A.csv as it contains no data records or less than 10 records.
# Skipping /gpfs/work3/0/ai4nbs/hurry_wave/north_sea/01_data/Waterinfo_RWS/2004/Platform D15-A.csv as it contains no data records or less than 10 records.
# Skipping /gpfs/work3/0/ai4nbs/hurry_wave/north_sea/01_data/Waterinfo_RWS/2004/K13 Alpha.csv as it contains no data records or less than 10 records.
# Finished loading observational data from Waterinfo_RWS for 8 stations.
# Loading observational data for year: 2003
# Skipping /gpfs/work3/0/ai4nbs/hurry_wave/north_sea/01_data/Waterinfo_RWS/2003/Platform Hoorn Q1-A.csv as it contains no data records or less than 10 records.
# Skipping /gpfs/work3/0/ai4nbs/hurry_wave/north_sea/01_data/Waterinfo_RWS/2003/Platform F16-A.csv as it contains no data records or less than 10 records.
# Skipping /gpfs/work3/0/ai4nbs/hurry_wave/north_sea/01_data/Waterinfo_RWS/2003/Platform D15-A.csv as it contains no data records or less than 10 records.
# Skipping /gpfs/work3/0/ai4nbs/hurry_wave/north_sea/01_data/Waterinfo_RWS/2003/K13 Alpha.csv as it contains no data records or less than 10 records.
# Finished loading observational data from Waterinfo_RWS for 8 stations.
# Loading observational data for year: 2002
# Skipping /gpfs/work3/0/ai4nbs/hurry_wave/north_sea/01_data/Waterinfo_RWS/2002/Platform Hoorn Q1-A.csv as it contains no data records or less than 10 records.
# Skipping /gpfs/work3/0/ai4nbs/hurry_wave/north_sea/01_data/Waterinfo_RWS/2002/Platform F16-A.csv as it contains no data records or less than 10 records.
# Skipping /gpfs/work3/0/ai4nbs/hurry_wave/north_sea/01_data/Waterinfo_RWS/2002/Platform D15-A.csv as it contains no data records or less than 10 records.
# Skipping /gpfs/work3/0/ai4nbs/hurry_wave/north_sea/01_data/Waterinfo_RWS/2002/K13 Alpha.csv as it contains no data records or less than 10 records.
# Finished loading observational data from Waterinfo_RWS for 8 stations.
# Loading observational data for year: 2001
# Skipping /gpfs/work3/0/ai4nbs/hurry_wave/north_sea/01_data/Waterinfo_RWS/2001/Platform Hoorn Q1-A.csv as it contains no data records or less than 10 records.
# Skipping /gpfs/work3/0/ai4nbs/hurry_wave/north_sea/01_data/Waterinfo_RWS/2001/Platform F16-A.csv as it contains no data records or less than 10 records.
# Skipping /gpfs/work3/0/ai4nbs/hurry_wave/north_sea/01_data/Waterinfo_RWS/2001/Platform D15-A.csv as it contains no data records or less than 10 records.
# Skipping /gpfs/work3/0/ai4nbs/hurry_wave/north_sea/01_data/Waterinfo_RWS/2001/K13 Alpha.csv as it contains no data records or less than 10 records.
# Skipping /gpfs/work3/0/ai4nbs/hurry_wave/north_sea/01_data/Waterinfo_RWS/2001/North Cormorant.csv as it contains no data records or less than 10 records.
# Finished loading observational data from Waterinfo_RWS for 8 stations.
# Loading observational data for year: 2000
# Skipping /gpfs/work3/0/ai4nbs/hurry_wave/north_sea/01_data/Waterinfo_RWS/2000/Platform Hoorn Q1-A.csv as it contains no data records or less than 10 records.
# Skipping /gpfs/work3/0/ai4nbs/hurry_wave/north_sea/01_data/Waterinfo_RWS/2000/Platform F16-A.csv as it contains no data records or less than 10 records.
# Skipping /gpfs/work3/0/ai4nbs/hurry_wave/north_sea/01_data/Waterinfo_RWS/2000/Platform D15-A.csv as it contains no data records or less than 10 records.
# Skipping /gpfs/work3/0/ai4nbs/hurry_wave/north_sea/01_data/Waterinfo_RWS/2000/K13 Alpha.csv as it contains no data records or less than 10 records.
# Skipping /gpfs/work3/0/ai4nbs/hurry_wave/north_sea/01_data/Waterinfo_RWS/2000/North Cormorant.csv as it contains no data records or less than 10 records.
# Finished loading observational data from Waterinfo_RWS for 8 stations.
# Loading observational data for year: 1999
# Skipping /gpfs/work3/0/ai4nbs/hurry_wave/north_sea/01_data/Waterinfo_RWS/1999/Platform Hoorn Q1-A.csv as it contains no data records or less than 10 records.
# Skipping /gpfs/work3/0/ai4nbs/hurry_wave/north_sea/01_data/Waterinfo_RWS/1999/Platform F16-A.csv as it contains no data records or less than 10 records.
# Skipping /gpfs/work3/0/ai4nbs/hurry_wave/north_sea/01_data/Waterinfo_RWS/1999/Platform D15-A.csv as it contains no data records or less than 10 records.
# Skipping /gpfs/work3/0/ai4nbs/hurry_wave/north_sea/01_data/Waterinfo_RWS/1999/K13 Alpha.csv as it contains no data records or less than 10 records.
# Skipping /gpfs/work3/0/ai4nbs/hurry_wave/north_sea/01_data/Waterinfo_RWS/1999/North Cormorant.csv as it contains no data records or less than 10 records.
# Finished loading observational data from Waterinfo_RWS for 8 stations.
# Loading observational data for year: 1998
# Skipping /gpfs/work3/0/ai4nbs/hurry_wave/north_sea/01_data/Waterinfo_RWS/1998/Platform Hoorn Q1-A.csv as it contains no data records or less than 10 records.
# Skipping /gpfs/work3/0/ai4nbs/hurry_wave/north_sea/01_data/Waterinfo_RWS/1998/Platform F16-A.csv as it contains no data records or less than 10 records.
# Skipping /gpfs/work3/0/ai4nbs/hurry_wave/north_sea/01_data/Waterinfo_RWS/1998/Platform D15-A.csv as it contains no data records or less than 10 records.
# Skipping /gpfs/work3/0/ai4nbs/hurry_wave/north_sea/01_data/Waterinfo_RWS/1998/K13 Alpha.csv as it contains no data records or less than 10 records.
# Skipping /gpfs/work3/0/ai4nbs/hurry_wave/north_sea/01_data/Waterinfo_RWS/1998/North Cormorant.csv as it contains no data records or less than 10 records.
# Finished loading observational data from Waterinfo_RWS for 8 stations.
# Loading observational data for year: 1997
# Skipping /gpfs/work3/0/ai4nbs/hurry_wave/north_sea/01_data/Waterinfo_RWS/1997/Platform Hoorn Q1-A.csv as it contains no data records or less than 10 records.
# Skipping /gpfs/work3/0/ai4nbs/hurry_wave/north_sea/01_data/Waterinfo_RWS/1997/Platform F16-A.csv as it contains no data records or less than 10 records.
# Skipping /gpfs/work3/0/ai4nbs/hurry_wave/north_sea/01_data/Waterinfo_RWS/1997/Platform D15-A.csv as it contains no data records or less than 10 records.
# Skipping /gpfs/work3/0/ai4nbs/hurry_wave/north_sea/01_data/Waterinfo_RWS/1997/K13 Alpha.csv as it contains no data records or less than 10 records.
# Skipping /gpfs/work3/0/ai4nbs/hurry_wave/north_sea/01_data/Waterinfo_RWS/1997/North Cormorant.csv as it contains no data records or less than 10 records.
# Finished loading observational data from Waterinfo_RWS for 8 stations.
# Loading observational data for year: 1996
# Skipping /gpfs/work3/0/ai4nbs/hurry_wave/north_sea/01_data/Waterinfo_RWS/1996/Platform Hoorn Q1-A.csv as it contains no data records or less than 10 records.
# Skipping /gpfs/work3/0/ai4nbs/hurry_wave/north_sea/01_data/Waterinfo_RWS/1996/Platform F16-A.csv as it contains no data records or less than 10 records.
# Skipping /gpfs/work3/0/ai4nbs/hurry_wave/north_sea/01_data/Waterinfo_RWS/1996/Platform D15-A.csv as it contains no data records or less than 10 records.
# Skipping /gpfs/work3/0/ai4nbs/hurry_wave/north_sea/01_data/Waterinfo_RWS/1996/K13 Alpha.csv as it contains no data records or less than 10 records.
# Skipping /gpfs/work3/0/ai4nbs/hurry_wave/north_sea/01_data/Waterinfo_RWS/1996/North Cormorant.csv as it contains no data records or less than 10 records.
# Finished loading observational data from Waterinfo_RWS for 8 stations.
# Loading observational data for year: 1995
# Skipping /gpfs/work3/0/ai4nbs/hurry_wave/north_sea/01_data/Waterinfo_RWS/1995/Platform Hoorn Q1-A.csv as it contains no data records or less than 10 records.
# Skipping /gpfs/work3/0/ai4nbs/hurry_wave/north_sea/01_data/Waterinfo_RWS/1995/Platform F16-A.csv as it contains no data records or less than 10 records.
# Skipping /gpfs/work3/0/ai4nbs/hurry_wave/north_sea/01_data/Waterinfo_RWS/1995/Platform D15-A.csv as it contains no data records or less than 10 records.
# Skipping /gpfs/work3/0/ai4nbs/hurry_wave/north_sea/01_data/Waterinfo_RWS/1995/K13 Alpha.csv as it contains no data records or less than 10 records.
# Skipping /gpfs/work3/0/ai4nbs/hurry_wave/north_sea/01_data/Waterinfo_RWS/1995/North Cormorant.csv as it contains no data records or less than 10 records.
# Finished loading observational data from Waterinfo_RWS for 8 stations.
# Loading observational data for year: 1994
# Skipping /gpfs/work3/0/ai4nbs/hurry_wave/north_sea/01_data/Waterinfo_RWS/1994/Platform Hoorn Q1-A.csv as it contains no data records or less than 10 records.
# Skipping /gpfs/work3/0/ai4nbs/hurry_wave/north_sea/01_data/Waterinfo_RWS/1994/Platform F16-A.csv as it contains no data records or less than 10 records.
# Skipping /gpfs/work3/0/ai4nbs/hurry_wave/north_sea/01_data/Waterinfo_RWS/1994/Platform D15-A.csv as it contains no data records or less than 10 records.
# Skipping /gpfs/work3/0/ai4nbs/hurry_wave/north_sea/01_data/Waterinfo_RWS/1994/K13 Alpha.csv as it contains no data records or less than 10 records.
# Skipping /gpfs/work3/0/ai4nbs/hurry_wave/north_sea/01_data/Waterinfo_RWS/1994/North Cormorant.csv as it contains no data records or less than 10 records.
# Finished loading observational data from Waterinfo_RWS for 8 stations.
# Loading observational data for year: 1993
# Skipping /gpfs/work3/0/ai4nbs/hurry_wave/north_sea/01_data/Waterinfo_RWS/1993/Platform Hoorn Q1-A.csv as it contains no data records or less than 10 records.
# Skipping /gpfs/work3/0/ai4nbs/hurry_wave/north_sea/01_data/Waterinfo_RWS/1993/Platform F16-A.csv as it contains no data records or less than 10 records.
# Skipping /gpfs/work3/0/ai4nbs/hurry_wave/north_sea/01_data/Waterinfo_RWS/1993/Platform D15-A.csv as it contains no data records or less than 10 records.
# Skipping /gpfs/work3/0/ai4nbs/hurry_wave/north_sea/01_data/Waterinfo_RWS/1993/K13 Alpha.csv as it contains no data records or less than 10 records.
# Skipping /gpfs/work3/0/ai4nbs/hurry_wave/north_sea/01_data/Waterinfo_RWS/1993/North Cormorant.csv as it contains no data records or less than 10 records.
# Finished loading observational data from Waterinfo_RWS for 8 stations.
# Loading observational data for year: 1992
# Skipping /gpfs/work3/0/ai4nbs/hurry_wave/north_sea/01_data/Waterinfo_RWS/1992/Platform Hoorn Q1-A.csv as it contains no data records or less than 10 records.
# Skipping /gpfs/work3/0/ai4nbs/hurry_wave/north_sea/01_data/Waterinfo_RWS/1992/Platform F16-A.csv as it contains no data records or less than 10 records.
# Skipping /gpfs/work3/0/ai4nbs/hurry_wave/north_sea/01_data/Waterinfo_RWS/1992/Platform D15-A.csv as it contains no data records or less than 10 records.
# Skipping /gpfs/work3/0/ai4nbs/hurry_wave/north_sea/01_data/Waterinfo_RWS/1992/K13 Alpha.csv as it contains no data records or less than 10 records.
# Skipping /gpfs/work3/0/ai4nbs/hurry_wave/north_sea/01_data/Waterinfo_RWS/1992/North Cormorant.csv as it contains no data records or less than 10 records.
# Finished loading observational data from Waterinfo_RWS for 8 stations.
# Loading observational data for year: 1991
# Skipping /gpfs/work3/0/ai4nbs/hurry_wave/north_sea/01_data/Waterinfo_RWS/1991/Platform Hoorn Q1-A.csv as it contains no data records or less than 10 records.
# Skipping /gpfs/work3/0/ai4nbs/hurry_wave/north_sea/01_data/Waterinfo_RWS/1991/Platform F16-A.csv as it contains no data records or less than 10 records.
# Skipping /gpfs/work3/0/ai4nbs/hurry_wave/north_sea/01_data/Waterinfo_RWS/1991/Platform D15-A.csv as it contains no data records or less than 10 records.
# Skipping /gpfs/work3/0/ai4nbs/hurry_wave/north_sea/01_data/Waterinfo_RWS/1991/K13 Alpha.csv as it contains no data records or less than 10 records.
# Skipping /gpfs/work3/0/ai4nbs/hurry_wave/north_sea/01_data/Waterinfo_RWS/1991/North Cormorant.csv as it contains no data records or less than 10 records.
# Finished loading observational data from Waterinfo_RWS for 8 stations.
# Loading observational data for year: 1990
# Skipping /gpfs/work3/0/ai4nbs/hurry_wave/north_sea/01_data/Waterinfo_RWS/1990/Platform Hoorn Q1-A.csv as it contains no data records or less than 10 records.
# Skipping /gpfs/work3/0/ai4nbs/hurry_wave/north_sea/01_data/Waterinfo_RWS/1990/Platform F16-A.csv as it contains no data records or less than 10 records.
# Skipping /gpfs/work3/0/ai4nbs/hurry_wave/north_sea/01_data/Waterinfo_RWS/1990/Platform D15-A.csv as it contains no data records or less than 10 records.
# Skipping /gpfs/work3/0/ai4nbs/hurry_wave/north_sea/01_data/Waterinfo_RWS/1990/K13 Alpha.csv as it contains no data records or less than 10 records.
# Skipping /gpfs/work3/0/ai4nbs/hurry_wave/north_sea/01_data/Waterinfo_RWS/1990/North Cormorant.csv as it contains no data records or less than 10 records.
# Finished loading observational data from Waterinfo_RWS for 8 stations.
# Loading observational data for year: 1989
# Skipping /gpfs/work3/0/ai4nbs/hurry_wave/north_sea/01_data/Waterinfo_RWS/1989/Platform Hoorn Q1-A.csv as it contains no data records or less than 10 records.
# Skipping /gpfs/work3/0/ai4nbs/hurry_wave/north_sea/01_data/Waterinfo_RWS/1989/Platform F16-A.csv as it contains no data records or less than 10 records.
# Skipping /gpfs/work3/0/ai4nbs/hurry_wave/north_sea/01_data/Waterinfo_RWS/1989/Platform D15-A.csv as it contains no data records or less than 10 records.
# Skipping /gpfs/work3/0/ai4nbs/hurry_wave/north_sea/01_data/Waterinfo_RWS/1989/K13 Alpha.csv as it contains no data records or less than 10 records.
# Finished loading observational data from Waterinfo_RWS for 8 stations.
# Loading observational data for year: 1988
# Skipping /gpfs/work3/0/ai4nbs/hurry_wave/north_sea/01_data/Waterinfo_RWS/1988/Platform Hoorn Q1-A.csv as it contains no data records or less than 10 records.
# Skipping /gpfs/work3/0/ai4nbs/hurry_wave/north_sea/01_data/Waterinfo_RWS/1988/Platform F16-A.csv as it contains no data records or less than 10 records.
# Skipping /gpfs/work3/0/ai4nbs/hurry_wave/north_sea/01_data/Waterinfo_RWS/1988/Platform D15-A.csv as it contains no data records or less than 10 records.
# Skipping /gpfs/work3/0/ai4nbs/hurry_wave/north_sea/01_data/Waterinfo_RWS/1988/K13 Alpha.csv as it contains no data records or less than 10 records.
# Finished loading observational data from Waterinfo_RWS for 8 stations.
# Loading observational data for year: 1987
# Skipping /gpfs/work3/0/ai4nbs/hurry_wave/north_sea/01_data/Waterinfo_RWS/1987/Platform Hoorn Q1-A.csv as it contains no data records or less than 10 records.
# Skipping /gpfs/work3/0/ai4nbs/hurry_wave/north_sea/01_data/Waterinfo_RWS/1987/Platform F16-A.csv as it contains no data records or less than 10 records.
# Skipping /gpfs/work3/0/ai4nbs/hurry_wave/north_sea/01_data/Waterinfo_RWS/1987/Platform D15-A.csv as it contains no data records or less than 10 records.
# Skipping /gpfs/work3/0/ai4nbs/hurry_wave/north_sea/01_data/Waterinfo_RWS/1987/K13 Alpha.csv as it contains no data records or less than 10 records.
# Finished loading observational data from Waterinfo_RWS for 8 stations.
# Loading observational data for year: 1986
# Skipping /gpfs/work3/0/ai4nbs/hurry_wave/north_sea/01_data/Waterinfo_RWS/1986/Platform Hoorn Q1-A.csv as it contains no data records or less than 10 records.
# Skipping /gpfs/work3/0/ai4nbs/hurry_wave/north_sea/01_data/Waterinfo_RWS/1986/Platform F16-A.csv as it contains no data records or less than 10 records.
# Skipping /gpfs/work3/0/ai4nbs/hurry_wave/north_sea/01_data/Waterinfo_RWS/1986/Platform D15-A.csv as it contains no data records or less than 10 records.
# Skipping /gpfs/work3/0/ai4nbs/hurry_wave/north_sea/01_data/Waterinfo_RWS/1986/K13 Alpha.csv as it contains no data records or less than 10 records.
# Skipping /gpfs/work3/0/ai4nbs/hurry_wave/north_sea/01_data/Waterinfo_RWS/1986/North Cormorant.csv as it contains no data records or less than 10 records.
# Finished loading observational data from Waterinfo_RWS for 8 stations.
# Loading observational data for year: 1985
# Skipping /gpfs/work3/0/ai4nbs/hurry_wave/north_sea/01_data/Waterinfo_RWS/1985/Platform Hoorn Q1-A.csv as it contains no data records or less than 10 records.
# Skipping /gpfs/work3/0/ai4nbs/hurry_wave/north_sea/01_data/Waterinfo_RWS/1985/Platform F16-A.csv as it contains no data records or less than 10 records.
# Skipping /gpfs/work3/0/ai4nbs/hurry_wave/north_sea/01_data/Waterinfo_RWS/1985/Platform D15-A.csv as it contains no data records or less than 10 records.
# Skipping /gpfs/work3/0/ai4nbs/hurry_wave/north_sea/01_data/Waterinfo_RWS/1985/K13 Alpha.csv as it contains no data records or less than 10 records.
# Skipping /gpfs/work3/0/ai4nbs/hurry_wave/north_sea/01_data/Waterinfo_RWS/1985/North Cormorant.csv as it contains no data records or less than 10 records.
# Finished loading observational data from Waterinfo_RWS for 8 stations.
# Loading observational data for year: 1984
# Skipping /gpfs/work3/0/ai4nbs/hurry_wave/north_sea/01_data/Waterinfo_RWS/1984/Platform Hoorn Q1-A.csv as it contains no data records or less than 10 records.
# Skipping /gpfs/work3/0/ai4nbs/hurry_wave/north_sea/01_data/Waterinfo_RWS/1984/Platform F16-A.csv as it contains no data records or less than 10 records.
# Skipping /gpfs/work3/0/ai4nbs/hurry_wave/north_sea/01_data/Waterinfo_RWS/1984/Platform D15-A.csv as it contains no data records or less than 10 records.
# Skipping /gpfs/work3/0/ai4nbs/hurry_wave/north_sea/01_data/Waterinfo_RWS/1984/K13 Alpha.csv as it contains no data records or less than 10 records.
# Skipping /gpfs/work3/0/ai4nbs/hurry_wave/north_sea/01_data/Waterinfo_RWS/1984/North Cormorant.csv as it contains no data records or less than 10 records.
# Finished loading observational data from Waterinfo_RWS for 8 stations.
# Loading observational data for year: 1983
# Skipping /gpfs/work3/0/ai4nbs/hurry_wave/north_sea/01_data/Waterinfo_RWS/1983/Platform Hoorn Q1-A.csv as it contains no data records or less than 10 records.
# Skipping /gpfs/work3/0/ai4nbs/hurry_wave/north_sea/01_data/Waterinfo_RWS/1983/Platform F16-A.csv as it contains no data records or less than 10 records.
# Skipping /gpfs/work3/0/ai4nbs/hurry_wave/north_sea/01_data/Waterinfo_RWS/1983/Platform D15-A.csv as it contains no data records or less than 10 records.
# Skipping /gpfs/work3/0/ai4nbs/hurry_wave/north_sea/01_data/Waterinfo_RWS/1983/K13 Alpha.csv as it contains no data records or less than 10 records.
# Skipping /gpfs/work3/0/ai4nbs/hurry_wave/north_sea/01_data/Waterinfo_RWS/1983/North Cormorant.csv as it contains no data records or less than 10 records.
# Finished loading observational data from Waterinfo_RWS for 8 stations.
# Loading observational data for year: 1982
# Skipping /gpfs/work3/0/ai4nbs/hurry_wave/north_sea/01_data/Waterinfo_RWS/1982/Platform Hoorn Q1-A.csv as it contains no data records or less than 10 records.
# Skipping /gpfs/work3/0/ai4nbs/hurry_wave/north_sea/01_data/Waterinfo_RWS/1982/Platform F16-A.csv as it contains no data records or less than 10 records.
# Skipping /gpfs/work3/0/ai4nbs/hurry_wave/north_sea/01_data/Waterinfo_RWS/1982/Platform D15-A.csv as it contains no data records or less than 10 records.
# Skipping /gpfs/work3/0/ai4nbs/hurry_wave/north_sea/01_data/Waterinfo_RWS/1982/K13 Alpha.csv as it contains no data records or less than 10 records.
# Skipping /gpfs/work3/0/ai4nbs/hurry_wave/north_sea/01_data/Waterinfo_RWS/1982/North Cormorant.csv as it contains no data records or less than 10 records.
# Finished loading observational data from Waterinfo_RWS for 8 stations.
# Loading observational data for year: 1981
# Skipping /gpfs/work3/0/ai4nbs/hurry_wave/north_sea/01_data/Waterinfo_RWS/1981/Platform Hoorn Q1-A.csv as it contains no data records or less than 10 records.
# Skipping /gpfs/work3/0/ai4nbs/hurry_wave/north_sea/01_data/Waterinfo_RWS/1981/Platform F16-A.csv as it contains no data records or less than 10 records.
# Skipping /gpfs/work3/0/ai4nbs/hurry_wave/north_sea/01_data/Waterinfo_RWS/1981/Platform D15-A.csv as it contains no data records or less than 10 records.
# Skipping /gpfs/work3/0/ai4nbs/hurry_wave/north_sea/01_data/Waterinfo_RWS/1981/K13 Alpha.csv as it contains no data records or less than 10 records.
# Skipping /gpfs/work3/0/ai4nbs/hurry_wave/north_sea/01_data/Waterinfo_RWS/1981/North Cormorant.csv as it contains no data records or less than 10 records.
# Skipping /gpfs/work3/0/ai4nbs/hurry_wave/north_sea/01_data/Waterinfo_RWS/1981/Euro platform.csv as it contains no data records or less than 10 records.
# Finished loading observational data from Waterinfo_RWS for 8 stations.
# Loading observational data for year: 1980
# Skipping /gpfs/work3/0/ai4nbs/hurry_wave/north_sea/01_data/Waterinfo_RWS/1980/Platform Hoorn Q1-A.csv as it contains no data records or less than 10 records.
# Skipping /gpfs/work3/0/ai4nbs/hurry_wave/north_sea/01_data/Waterinfo_RWS/1980/Platform F16-A.csv as it contains no data records or less than 10 records.
# Skipping /gpfs/work3/0/ai4nbs/hurry_wave/north_sea/01_data/Waterinfo_RWS/1980/Platform D15-A.csv as it contains no data records or less than 10 records.
# Skipping /gpfs/work3/0/ai4nbs/hurry_wave/north_sea/01_data/Waterinfo_RWS/1980/K13 Alpha.csv as it contains no data records or less than 10 records.
# Skipping /gpfs/work3/0/ai4nbs/hurry_wave/north_sea/01_data/Waterinfo_RWS/1980/North Cormorant.csv as it contains no data records or less than 10 records.
# Skipping /gpfs/work3/0/ai4nbs/hurry_wave/north_sea/01_data/Waterinfo_RWS/1980/Euro platform.csv as it contains no data records or less than 10 records.
# Finished loading observational data from Waterinfo_RWS for 8 stations.
# Loading observational data for year: 1979
# Skipping /gpfs/work3/0/ai4nbs/hurry_wave/north_sea/01_data/Waterinfo_RWS/1979/Platform Hoorn Q1-A.csv as it contains no data records or less than 10 records.
# Skipping /gpfs/work3/0/ai4nbs/hurry_wave/north_sea/01_data/Waterinfo_RWS/1979/Platform F16-A.csv as it contains no data records or less than 10 records.
# Skipping /gpfs/work3/0/ai4nbs/hurry_wave/north_sea/01_data/Waterinfo_RWS/1979/Platform D15-A.csv as it contains no data records or less than 10 records.
# Skipping /gpfs/work3/0/ai4nbs/hurry_wave/north_sea/01_data/Waterinfo_RWS/1979/K13 Alpha.csv as it contains no data records or less than 10 records.
# Skipping /gpfs/work3/0/ai4nbs/hurry_wave/north_sea/01_data/Waterinfo_RWS/1979/North Cormorant.csv as it contains no data records or less than 10 records.
# Skipping /gpfs/work3/0/ai4nbs/hurry_wave/north_sea/01_data/Waterinfo_RWS/1979/Euro platform.csv as it contains no data records or less than 10 records.
# Finished loading observational data from Waterinfo_RWS for 8 stations.
# Loading observational data for year: 1978
# Skipping /gpfs/work3/0/ai4nbs/hurry_wave/north_sea/01_data/Waterinfo_RWS/1978/Platform Hoorn Q1-A.csv as it contains no data records or less than 10 records.
# Skipping /gpfs/work3/0/ai4nbs/hurry_wave/north_sea/01_data/Waterinfo_RWS/1978/Platform F16-A.csv as it contains no data records or less than 10 records.
# Skipping /gpfs/work3/0/ai4nbs/hurry_wave/north_sea/01_data/Waterinfo_RWS/1978/IJmuiden munitiestortplaats.csv as it contains no data records or less than 10 records.
# Skipping /gpfs/work3/0/ai4nbs/hurry_wave/north_sea/01_data/Waterinfo_RWS/1978/Platform D15-A.csv as it contains no data records or less than 10 records.
# Skipping /gpfs/work3/0/ai4nbs/hurry_wave/north_sea/01_data/Waterinfo_RWS/1978/K13 Alpha.csv as it contains no data records or less than 10 records.
# Skipping /gpfs/work3/0/ai4nbs/hurry_wave/north_sea/01_data/Waterinfo_RWS/1978/North Cormorant.csv as it contains no data records or less than 10 records.
# Skipping /gpfs/work3/0/ai4nbs/hurry_wave/north_sea/01_data/Waterinfo_RWS/1978/Euro platform.csv as it contains no data records or less than 10 records.
# Finished loading observational data from Waterinfo_RWS for 8 stations.
# Loading observational data for year: 1977
# Skipping /gpfs/work3/0/ai4nbs/hurry_wave/north_sea/01_data/Waterinfo_RWS/1977/Platform Hoorn Q1-A.csv as it contains no data records or less than 10 records.
# Skipping /gpfs/work3/0/ai4nbs/hurry_wave/north_sea/01_data/Waterinfo_RWS/1977/Platform F16-A.csv as it contains no data records or less than 10 records.
# Skipping /gpfs/work3/0/ai4nbs/hurry_wave/north_sea/01_data/Waterinfo_RWS/1977/Platform D15-A.csv as it contains no data records or less than 10 records.
# Skipping /gpfs/work3/0/ai4nbs/hurry_wave/north_sea/01_data/Waterinfo_RWS/1977/K13a platform.csv as it contains no data records or less than 10 records.
# Skipping /gpfs/work3/0/ai4nbs/hurry_wave/north_sea/01_data/Waterinfo_RWS/1977/K13 Alpha.csv as it contains no data records or less than 10 records.
# Skipping /gpfs/work3/0/ai4nbs/hurry_wave/north_sea/01_data/Waterinfo_RWS/1977/North Cormorant.csv as it contains no data records or less than 10 records.
# Skipping /gpfs/work3/0/ai4nbs/hurry_wave/north_sea/01_data/Waterinfo_RWS/1977/Euro platform.csv as it contains no data records or less than 10 records.
# Finished loading observational data from Waterinfo_RWS for 8 stations.
# Loading observational data for year: 1976
# Skipping /gpfs/work3/0/ai4nbs/hurry_wave/north_sea/01_data/Waterinfo_RWS/1976/Platform Hoorn Q1-A.csv as it contains no data records or less than 10 records.
# Skipping /gpfs/work3/0/ai4nbs/hurry_wave/north_sea/01_data/Waterinfo_RWS/1976/Platform F16-A.csv as it contains no data records or less than 10 records.
# Skipping /gpfs/work3/0/ai4nbs/hurry_wave/north_sea/01_data/Waterinfo_RWS/1976/Platform D15-A.csv as it contains no data records or less than 10 records.
# Skipping /gpfs/work3/0/ai4nbs/hurry_wave/north_sea/01_data/Waterinfo_RWS/1976/K13a platform.csv as it contains no data records or less than 10 records.
# Skipping /gpfs/work3/0/ai4nbs/hurry_wave/north_sea/01_data/Waterinfo_RWS/1976/K13 Alpha.csv as it contains no data records or less than 10 records.
# Skipping /gpfs/work3/0/ai4nbs/hurry_wave/north_sea/01_data/Waterinfo_RWS/1976/North Cormorant.csv as it contains no data records or less than 10 records.
# Skipping /gpfs/work3/0/ai4nbs/hurry_wave/north_sea/01_data/Waterinfo_RWS/1976/Euro platform.csv as it contains no data records or less than 10 records.
# Finished loading observational data from Waterinfo_RWS for 8 stations.
# Loading observational data for year: 1975
# Skipping /gpfs/work3/0/ai4nbs/hurry_wave/north_sea/01_data/Waterinfo_RWS/1975/Platform Hoorn Q1-A.csv as it contains no data records or less than 10 records.
# Skipping /gpfs/work3/0/ai4nbs/hurry_wave/north_sea/01_data/Waterinfo_RWS/1975/Platform F16-A.csv as it contains no data records or less than 10 records.
# Skipping /gpfs/work3/0/ai4nbs/hurry_wave/north_sea/01_data/Waterinfo_RWS/1975/IJmuiden munitiestortplaats.csv as it contains no data records or less than 10 records.
# Skipping /gpfs/work3/0/ai4nbs/hurry_wave/north_sea/01_data/Waterinfo_RWS/1975/Platform D15-A.csv as it contains no data records or less than 10 records.
# Skipping /gpfs/work3/0/ai4nbs/hurry_wave/north_sea/01_data/Waterinfo_RWS/1975/K13a platform.csv as it contains no data records or less than 10 records.
# Skipping /gpfs/work3/0/ai4nbs/hurry_wave/north_sea/01_data/Waterinfo_RWS/1975/K13 Alpha.csv as it contains no data records or less than 10 records.
# Skipping /gpfs/work3/0/ai4nbs/hurry_wave/north_sea/01_data/Waterinfo_RWS/1975/North Cormorant.csv as it contains no data records or less than 10 records.
# Skipping /gpfs/work3/0/ai4nbs/hurry_wave/north_sea/01_data/Waterinfo_RWS/1975/Euro platform.csv as it contains no data records or less than 10 records.
# Finished loading observational data from Waterinfo_RWS for 8 stations.
# Loading observational data for year: 1974
# Skipping /gpfs/work3/0/ai4nbs/hurry_wave/north_sea/01_data/Waterinfo_RWS/1974/Platform Hoorn Q1-A.csv as it contains no data records or less than 10 records.
# Skipping /gpfs/work3/0/ai4nbs/hurry_wave/north_sea/01_data/Waterinfo_RWS/1974/Platform F16-A.csv as it contains no data records or less than 10 records.
# Skipping /gpfs/work3/0/ai4nbs/hurry_wave/north_sea/01_data/Waterinfo_RWS/1974/IJmuiden munitiestortplaats.csv as it contains no data records or less than 10 records.
# Skipping /gpfs/work3/0/ai4nbs/hurry_wave/north_sea/01_data/Waterinfo_RWS/1974/Platform D15-A.csv as it contains no data records or less than 10 records.
# Skipping /gpfs/work3/0/ai4nbs/hurry_wave/north_sea/01_data/Waterinfo_RWS/1974/K13a platform.csv as it contains no data records or less than 10 records.
# Skipping /gpfs/work3/0/ai4nbs/hurry_wave/north_sea/01_data/Waterinfo_RWS/1974/K13 Alpha.csv as it contains no data records or less than 10 records.
# Skipping /gpfs/work3/0/ai4nbs/hurry_wave/north_sea/01_data/Waterinfo_RWS/1974/North Cormorant.csv as it contains no data records or less than 10 records.
# Skipping /gpfs/work3/0/ai4nbs/hurry_wave/north_sea/01_data/Waterinfo_RWS/1974/Euro platform.csv as it contains no data records or less than 10 records.
# Finished loading observational data from Waterinfo_RWS for 8 stations.
# Loading observational data for year: 1973
# Skipping /gpfs/work3/0/ai4nbs/hurry_wave/north_sea/01_data/Waterinfo_RWS/1973/Platform Hoorn Q1-A.csv as it contains no data records or less than 10 records.
# Skipping /gpfs/work3/0/ai4nbs/hurry_wave/north_sea/01_data/Waterinfo_RWS/1973/Platform F16-A.csv as it contains no data records or less than 10 records.
# Skipping /gpfs/work3/0/ai4nbs/hurry_wave/north_sea/01_data/Waterinfo_RWS/1973/IJmuiden munitiestortplaats.csv as it contains no data records or less than 10 records.
# Skipping /gpfs/work3/0/ai4nbs/hurry_wave/north_sea/01_data/Waterinfo_RWS/1973/Platform D15-A.csv as it contains no data records or less than 10 records.
# Skipping /gpfs/work3/0/ai4nbs/hurry_wave/north_sea/01_data/Waterinfo_RWS/1973/K13a platform.csv as it contains no data records or less than 10 records.
# Skipping /gpfs/work3/0/ai4nbs/hurry_wave/north_sea/01_data/Waterinfo_RWS/1973/K13 Alpha.csv as it contains no data records or less than 10 records.
# Skipping /gpfs/work3/0/ai4nbs/hurry_wave/north_sea/01_data/Waterinfo_RWS/1973/North Cormorant.csv as it contains no data records or less than 10 records.
# Skipping /gpfs/work3/0/ai4nbs/hurry_wave/north_sea/01_data/Waterinfo_RWS/1973/Euro platform.csv as it contains no data records or less than 10 records.
# Finished loading observational data from Waterinfo_RWS for 8 stations.
# Loading observational data for year: 1972
# Skipping /gpfs/work3/0/ai4nbs/hurry_wave/north_sea/01_data/Waterinfo_RWS/1972/Platform Hoorn Q1-A.csv as it contains no data records or less than 10 records.
# Skipping /gpfs/work3/0/ai4nbs/hurry_wave/north_sea/01_data/Waterinfo_RWS/1972/Platform F16-A.csv as it contains no data records or less than 10 records.
# Skipping /gpfs/work3/0/ai4nbs/hurry_wave/north_sea/01_data/Waterinfo_RWS/1972/IJmuiden munitiestortplaats.csv as it contains no data records or less than 10 records.
# Skipping /gpfs/work3/0/ai4nbs/hurry_wave/north_sea/01_data/Waterinfo_RWS/1972/Platform D15-A.csv as it contains no data records or less than 10 records.
# Skipping /gpfs/work3/0/ai4nbs/hurry_wave/north_sea/01_data/Waterinfo_RWS/1972/K13a platform.csv as it contains no data records or less than 10 records.
# Skipping /gpfs/work3/0/ai4nbs/hurry_wave/north_sea/01_data/Waterinfo_RWS/1972/K13 Alpha.csv as it contains no data records or less than 10 records.
# Skipping /gpfs/work3/0/ai4nbs/hurry_wave/north_sea/01_data/Waterinfo_RWS/1972/North Cormorant.csv as it contains no data records or less than 10 records.
# Skipping /gpfs/work3/0/ai4nbs/hurry_wave/north_sea/01_data/Waterinfo_RWS/1972/Euro platform.csv as it contains no data records or less than 10 records.
# Finished loading observational data from Waterinfo_RWS for 8 stations.
# Loading observational data for year: 1971
# Skipping /gpfs/work3/0/ai4nbs/hurry_wave/north_sea/01_data/Waterinfo_RWS/1971/Platform Hoorn Q1-A.csv as it contains no data records or less than 10 records.
# Skipping /gpfs/work3/0/ai4nbs/hurry_wave/north_sea/01_data/Waterinfo_RWS/1971/Platform F16-A.csv as it contains no data records or less than 10 records.
# Skipping /gpfs/work3/0/ai4nbs/hurry_wave/north_sea/01_data/Waterinfo_RWS/1971/IJmuiden munitiestortplaats.csv as it contains no data records or less than 10 records.
# Skipping /gpfs/work3/0/ai4nbs/hurry_wave/north_sea/01_data/Waterinfo_RWS/1971/Platform D15-A.csv as it contains no data records or less than 10 records.
# Skipping /gpfs/work3/0/ai4nbs/hurry_wave/north_sea/01_data/Waterinfo_RWS/1971/K13a platform.csv as it contains no data records or less than 10 records.
# Skipping /gpfs/work3/0/ai4nbs/hurry_wave/north_sea/01_data/Waterinfo_RWS/1971/K13 Alpha.csv as it contains no data records or less than 10 records.
# Skipping /gpfs/work3/0/ai4nbs/hurry_wave/north_sea/01_data/Waterinfo_RWS/1971/North Cormorant.csv as it contains no data records or less than 10 records.
# Skipping /gpfs/work3/0/ai4nbs/hurry_wave/north_sea/01_data/Waterinfo_RWS/1971/Euro platform.csv as it contains no data records or less than 10 records.
# Finished loading observational data from Waterinfo_RWS for 8 stations.
# Loading observational data for year: 1970
# Skipping /gpfs/work3/0/ai4nbs/hurry_wave/north_sea/01_data/Waterinfo_RWS/1970/Platform Hoorn Q1-A.csv as it contains no data records or less than 10 records.
# Skipping /gpfs/work3/0/ai4nbs/hurry_wave/north_sea/01_data/Waterinfo_RWS/1970/Platform F16-A.csv as it contains no data records or less than 10 records.
# Skipping /gpfs/work3/0/ai4nbs/hurry_wave/north_sea/01_data/Waterinfo_RWS/1970/IJmuiden munitiestortplaats.csv as it contains no data records or less than 10 records.
# Skipping /gpfs/work3/0/ai4nbs/hurry_wave/north_sea/01_data/Waterinfo_RWS/1970/Platform D15-A.csv as it contains no data records or less than 10 records.
# Skipping /gpfs/work3/0/ai4nbs/hurry_wave/north_sea/01_data/Waterinfo_RWS/1970/K13a platform.csv as it contains no data records or less than 10 records.
# Skipping /gpfs/work3/0/ai4nbs/hurry_wave/north_sea/01_data/Waterinfo_RWS/1970/North Cormorant.csv as it contains no data records or less than 10 records.
# Skipping /gpfs/work3/0/ai4nbs/hurry_wave/north_sea/01_data/Waterinfo_RWS/1970/Euro platform.csv as it contains no data records or less than 10 records.
# Finished loading observational data from Waterinfo_RWS for 8 stations.
# Loading observational data for year: 1969
# Skipping /gpfs/work3/0/ai4nbs/hurry_wave/north_sea/01_data/Waterinfo_RWS/1969/Platform Hoorn Q1-A.csv as it contains no data records or less than 10 records.
# Skipping /gpfs/work3/0/ai4nbs/hurry_wave/north_sea/01_data/Waterinfo_RWS/1969/Platform F16-A.csv as it contains no data records or less than 10 records.
# Skipping /gpfs/work3/0/ai4nbs/hurry_wave/north_sea/01_data/Waterinfo_RWS/1969/IJmuiden munitiestortplaats.csv as it contains no data records or less than 10 records.
# Skipping /gpfs/work3/0/ai4nbs/hurry_wave/north_sea/01_data/Waterinfo_RWS/1969/Platform D15-A.csv as it contains no data records or less than 10 records.
# Skipping /gpfs/work3/0/ai4nbs/hurry_wave/north_sea/01_data/Waterinfo_RWS/1969/K13a platform.csv as it contains no data records or less than 10 records.
# Skipping /gpfs/work3/0/ai4nbs/hurry_wave/north_sea/01_data/Waterinfo_RWS/1969/K13 Alpha.csv as it contains no data records or less than 10 records.
# Skipping /gpfs/work3/0/ai4nbs/hurry_wave/north_sea/01_data/Waterinfo_RWS/1969/North Cormorant.csv as it contains no data records or less than 10 records.
# Skipping /gpfs/work3/0/ai4nbs/hurry_wave/north_sea/01_data/Waterinfo_RWS/1969/Euro platform.csv as it contains no data records or less than 10 records.
# Finished loading observational data from Waterinfo_RWS for 8 stations.
# Loading observational data for year: 1968
# Skipping /gpfs/work3/0/ai4nbs/hurry_wave/north_sea/01_data/Waterinfo_RWS/1968/Platform Hoorn Q1-A.csv as it contains no data records or less than 10 records.
# Skipping /gpfs/work3/0/ai4nbs/hurry_wave/north_sea/01_data/Waterinfo_RWS/1968/Platform F16-A.csv as it contains no data records or less than 10 records.
# Skipping /gpfs/work3/0/ai4nbs/hurry_wave/north_sea/01_data/Waterinfo_RWS/1968/IJmuiden munitiestortplaats.csv as it contains no data records or less than 10 records.
# Skipping /gpfs/work3/0/ai4nbs/hurry_wave/north_sea/01_data/Waterinfo_RWS/1968/Platform D15-A.csv as it contains no data records or less than 10 records.
# Skipping /gpfs/work3/0/ai4nbs/hurry_wave/north_sea/01_data/Waterinfo_RWS/1968/K13a platform.csv as it contains no data records or less than 10 records.
# Skipping /gpfs/work3/0/ai4nbs/hurry_wave/north_sea/01_data/Waterinfo_RWS/1968/K13 Alpha.csv as it contains no data records or less than 10 records.
# Skipping /gpfs/work3/0/ai4nbs/hurry_wave/north_sea/01_data/Waterinfo_RWS/1968/North Cormorant.csv as it contains no data records or less than 10 records.
# Skipping /gpfs/work3/0/ai4nbs/hurry_wave/north_sea/01_data/Waterinfo_RWS/1968/Euro platform.csv as it contains no data records or less than 10 records.
# Finished loading observational data from Waterinfo_RWS for 8 stations.
# Loading observational data for year: 1967
# Skipping /gpfs/work3/0/ai4nbs/hurry_wave/north_sea/01_data/Waterinfo_RWS/1967/Platform Hoorn Q1-A.csv as it contains no data records or less than 10 records.
# Skipping /gpfs/work3/0/ai4nbs/hurry_wave/north_sea/01_data/Waterinfo_RWS/1967/Platform F16-A.csv as it contains no data records or less than 10 records.
# Skipping /gpfs/work3/0/ai4nbs/hurry_wave/north_sea/01_data/Waterinfo_RWS/1967/IJmuiden munitiestortplaats.csv as it contains no data records or less than 10 records.
# Skipping /gpfs/work3/0/ai4nbs/hurry_wave/north_sea/01_data/Waterinfo_RWS/1967/Platform D15-A.csv as it contains no data records or less than 10 records.
# Skipping /gpfs/work3/0/ai4nbs/hurry_wave/north_sea/01_data/Waterinfo_RWS/1967/K13a platform.csv as it contains no data records or less than 10 records.
# Skipping /gpfs/work3/0/ai4nbs/hurry_wave/north_sea/01_data/Waterinfo_RWS/1967/K13 Alpha.csv as it contains no data records or less than 10 records.
# Skipping /gpfs/work3/0/ai4nbs/hurry_wave/north_sea/01_data/Waterinfo_RWS/1967/North Cormorant.csv as it contains no data records or less than 10 records.
# Skipping /gpfs/work3/0/ai4nbs/hurry_wave/north_sea/01_data/Waterinfo_RWS/1967/Euro platform.csv as it contains no data records or less than 10 records.
# Finished loading observational data from Waterinfo_RWS for 8 stations.
# Loading observational data for year: 1966
# Skipping /gpfs/work3/0/ai4nbs/hurry_wave/north_sea/01_data/Waterinfo_RWS/1966/Platform Hoorn Q1-A.csv as it contains no data records or less than 10 records.
# Skipping /gpfs/work3/0/ai4nbs/hurry_wave/north_sea/01_data/Waterinfo_RWS/1966/Platform F16-A.csv as it contains no data records or less than 10 records.
# Skipping /gpfs/work3/0/ai4nbs/hurry_wave/north_sea/01_data/Waterinfo_RWS/1966/IJmuiden munitiestortplaats.csv as it contains no data records or less than 10 records.
# Skipping /gpfs/work3/0/ai4nbs/hurry_wave/north_sea/01_data/Waterinfo_RWS/1966/Platform D15-A.csv as it contains no data records or less than 10 records.
# Skipping /gpfs/work3/0/ai4nbs/hurry_wave/north_sea/01_data/Waterinfo_RWS/1966/K13a platform.csv as it contains no data records or less than 10 records.
# Skipping /gpfs/work3/0/ai4nbs/hurry_wave/north_sea/01_data/Waterinfo_RWS/1966/K13 Alpha.csv as it contains no data records or less than 10 records.
# Skipping /gpfs/work3/0/ai4nbs/hurry_wave/north_sea/01_data/Waterinfo_RWS/1966/North Cormorant.csv as it contains no data records or less than 10 records.
# Skipping /gpfs/work3/0/ai4nbs/hurry_wave/north_sea/01_data/Waterinfo_RWS/1966/Euro platform.csv as it contains no data records or less than 10 records.
# Finished loading observational data from Waterinfo_RWS for 8 stations.
# Loading observational data for year: 1965
# Skipping /gpfs/work3/0/ai4nbs/hurry_wave/north_sea/01_data/Waterinfo_RWS/1965/Platform Hoorn Q1-A.csv as it contains no data records or less than 10 records.
# Skipping /gpfs/work3/0/ai4nbs/hurry_wave/north_sea/01_data/Waterinfo_RWS/1965/Platform F16-A.csv as it contains no data records or less than 10 records.
# Skipping /gpfs/work3/0/ai4nbs/hurry_wave/north_sea/01_data/Waterinfo_RWS/1965/IJmuiden munitiestortplaats.csv as it contains no data records or less than 10 records.
# ...
# Skipping /gpfs/work3/0/ai4nbs/hurry_wave/north_sea/01_data/Waterinfo_RWS/1961/Euro platform.csv as it contains no data records or less than 10 records.
# Finished loading observational data from Waterinfo_RWS for 8 stations.
# Loading observational data for year: 1960
# Skipping /gpfs/work3/0/ai4nbs/hurry_wave/north_sea/01_data/Waterinfo_RWS/1960/Platform Hoorn Q1-A.csv as it contains no data records or less than 10 records.
# Skipping /gpfs/work3/0/ai4nbs/hurry_wave/north_sea/01_data/Waterinfo_RWS/1960/Platform F16-A.csv as it contains no data records or less than 10 records.
# Skipping /gpfs/work3/0/ai4nbs/hurry_wave/north_sea/01_data/Waterinfo_RWS/1960/IJmuiden munitiestortplaats.csv as it contains no data records or less than 10 records.
# Skipping /gpfs/work3/0/ai4nbs/hurry_wave/north_sea/01_data/Waterinfo_RWS/1960/Platform D15-A.csv as it contains no data records or less than 10 records.
# Skipping /gpfs/work3/0/ai4nbs/hurry_wave/north_sea/01_data/Waterinfo_RWS/1960/K13a platform.csv as it contains no data records or less than 10 records.
# Skipping /gpfs/work3/0/ai4nbs/hurry_wave/north_sea/01_data/Waterinfo_RWS/1960/K13 Alpha.csv as it contains no data records or less than 10 records.
# Skipping /gpfs/work3/0/ai4nbs/hurry_wave/north_sea/01_data/Waterinfo_RWS/1960/North Cormorant.csv as it contains no data records or less than 10 records.
# Skipping /gpfs/work3/0/ai4nbs/hurry_wave/north_sea/01_data/Waterinfo_RWS/1960/Euro platform.csv as it contains no data records or less than 10 records.
# Finished loading observational data from Waterinfo_RWS for 8 stations.
# Loading observational data for year: 1959
# Skipping /gpfs/work3/0/ai4nbs/hurry_wave/north_sea/01_data/Waterinfo_RWS/1959/Platform Hoorn Q1-A.csv as it contains no data records or less than 10 records.
# Skipping /gpfs/work3/0/ai4nbs/hurry_wave/north_sea/01_data/Waterinfo_RWS/1959/Platform F16-A.csv as it contains no data records or less than 10 records.
# Skipping /gpfs/work3/0/ai4nbs/hurry_wave/north_sea/01_data/Waterinfo_RWS/1959/IJmuiden munitiestortplaats.csv as it contains no data records or less than 10 records.
# Skipping /gpfs/work3/0/ai4nbs/hurry_wave/north_sea/01_data/Waterinfo_RWS/1959/Platform D15-A.csv as it contains no data records or less than 10 records.
# Skipping /gpfs/work3/0/ai4nbs/hurry_wave/north_sea/01_data/Waterinfo_RWS/1959/K13a platform.csv as it contains no data records or less than 10 records.
# Skipping /gpfs/work3/0/ai4nbs/hurry_wave/north_sea/01_data/Waterinfo_RWS/1959/K13 Alpha.csv as it contains no data records or less than 10 records.
# Skipping /gpfs/work3/0/ai4nbs/hurry_wave/north_sea/01_data/Waterinfo_RWS/1959/North Cormorant.csv as it contains no data records or less than 10 records.
# Skipping /gpfs/work3/0/ai4nbs/hurry_wave/north_sea/01_data/Waterinfo_RWS/1959/Euro platform.csv as it contains no data records or less than 10 records.
# Finished loading observational data from Waterinfo_RWS for 8 stations.
# Loading observational data for year: 1958
# Skipping /gpfs/work3/0/ai4nbs/hurry_wave/north_sea/01_data/Waterinfo_RWS/1958/Platform Hoorn Q1-A.csv as it contains no data records or less than 10 records.
# Skipping /gpfs/work3/0/ai4nbs/hurry_wave/north_sea/01_data/Waterinfo_RWS/1958/Platform F16-A.csv as it contains no data records or less than 10 records.
# Skipping /gpfs/work3/0/ai4nbs/hurry_wave/north_sea/01_data/Waterinfo_RWS/1958/IJmuiden munitiestortplaats.csv as it contains no data records or less than 10 records.
# Skipping /gpfs/work3/0/ai4nbs/hurry_wave/north_sea/01_data/Waterinfo_RWS/1958/Platform D15-A.csv as it contains no data records or less than 10 records.
# Skipping /gpfs/work3/0/ai4nbs/hurry_wave/north_sea/01_data/Waterinfo_RWS/1958/K13a platform.csv as it contains no data records or less than 10 records.
# Skipping /gpfs/work3/0/ai4nbs/hurry_wave/north_sea/01_data/Waterinfo_RWS/1958/K13 Alpha.csv as it contains no data records or less than 10 records.
# Skipping /gpfs/work3/0/ai4nbs/hurry_wave/north_sea/01_data/Waterinfo_RWS/1958/North Cormorant.csv as it contains no data records or less than 10 records.
# Skipping /gpfs/work3/0/ai4nbs/hurry_wave/north_sea/01_data/Waterinfo_RWS/1958/Euro platform.csv as it contains no data records or less than 10 records.
# Finished loading observational data from Waterinfo_RWS for 8 stations.
# Loading observational data for year: 1957
# Skipping /gpfs/work3/0/ai4nbs/hurry_wave/north_sea/01_data/Waterinfo_RWS/1957/Platform Hoorn Q1-A.csv as it contains no data records or less than 10 records.
# Skipping /gpfs/work3/0/ai4nbs/hurry_wave/north_sea/01_data/Waterinfo_RWS/1957/Platform F16-A.csv as it contains no data records or less than 10 records.
# Skipping /gpfs/work3/0/ai4nbs/hurry_wave/north_sea/01_data/Waterinfo_RWS/1957/IJmuiden munitiestortplaats.csv as it contains no data records or less than 10 records.
# Skipping /gpfs/work3/0/ai4nbs/hurry_wave/north_sea/01_data/Waterinfo_RWS/1957/Platform D15-A.csv as it contains no data records or less than 10 records.
# Skipping /gpfs/work3/0/ai4nbs/hurry_wave/north_sea/01_data/Waterinfo_RWS/1957/K13a platform.csv as it contains no data records or less than 10 records.
# Skipping /gpfs/work3/0/ai4nbs/hurry_wave/north_sea/01_data/Waterinfo_RWS/1957/K13 Alpha.csv as it contains no data records or less than 10 records.
# Skipping /gpfs/work3/0/ai4nbs/hurry_wave/north_sea/01_data/Waterinfo_RWS/1957/North Cormorant.csv as it contains no data records or less than 10 records.
# Skipping /gpfs/work3/0/ai4nbs/hurry_wave/north_sea/01_data/Waterinfo_RWS/1957/Euro platform.csv as it contains no data records or less than 10 records.
# Finished loading observational data from Waterinfo_RWS for 8 stations.
# Loading observational data for year: 1956
# Skipping /gpfs/work3/0/ai4nbs/hurry_wave/north_sea/01_data/Waterinfo_RWS/1956/Platform Hoorn Q1-A.csv as it contains no data records or less than 10 records.
# Skipping /gpfs/work3/0/ai4nbs/hurry_wave/north_sea/01_data/Waterinfo_RWS/1956/Platform F16-A.csv as it contains no data records or less than 10 records.
# Skipping /gpfs/work3/0/ai4nbs/hurry_wave/north_sea/01_data/Waterinfo_RWS/1956/IJmuiden munitiestortplaats.csv as it contains no data records or less than 10 records.
# Skipping /gpfs/work3/0/ai4nbs/hurry_wave/north_sea/01_data/Waterinfo_RWS/1956/Platform D15-A.csv as it contains no data records or less than 10 records.
# Skipping /gpfs/work3/0/ai4nbs/hurry_wave/north_sea/01_data/Waterinfo_RWS/1956/K13a platform.csv as it contains no data records or less than 10 records.
# Skipping /gpfs/work3/0/ai4nbs/hurry_wave/north_sea/01_data/Waterinfo_RWS/1956/K13 Alpha.csv as it contains no data records or less than 10 records.
# Skipping /gpfs/work3/0/ai4nbs/hurry_wave/north_sea/01_data/Waterinfo_RWS/1956/North Cormorant.csv as it contains no data records or less than 10 records.
# Skipping /gpfs/work3/0/ai4nbs/hurry_wave/north_sea/01_data/Waterinfo_RWS/1956/Euro platform.csv as it contains no data records or less than 10 records.
# Finished loading observational data from Waterinfo_RWS for 8 stations.
# Loading observational data for year: 1955
# Skipping /gpfs/work3/0/ai4nbs/hurry_wave/north_sea/01_data/Waterinfo_RWS/1955/Platform Hoorn Q1-A.csv as it contains no data records or less than 10 records.
# Skipping /gpfs/work3/0/ai4nbs/hurry_wave/north_sea/01_data/Waterinfo_RWS/1955/Platform F16-A.csv as it contains no data records or less than 10 records.
# Skipping /gpfs/work3/0/ai4nbs/hurry_wave/north_sea/01_data/Waterinfo_RWS/1955/IJmuiden munitiestortplaats.csv as it contains no data records or less than 10 records.
# Skipping /gpfs/work3/0/ai4nbs/hurry_wave/north_sea/01_data/Waterinfo_RWS/1955/Platform D15-A.csv as it contains no data records or less than 10 records.
# Skipping /gpfs/work3/0/ai4nbs/hurry_wave/north_sea/01_data/Waterinfo_RWS/1955/K13a platform.csv as it contains no data records or less than 10 records.
# Skipping /gpfs/work3/0/ai4nbs/hurry_wave/north_sea/01_data/Waterinfo_RWS/1955/K13 Alpha.csv as it contains no data records or less than 10 records.
# Skipping /gpfs/work3/0/ai4nbs/hurry_wave/north_sea/01_data/Waterinfo_RWS/1955/North Cormorant.csv as it contains no data records or less than 10 records.
# Skipping /gpfs/work3/0/ai4nbs/hurry_wave/north_sea/01_data/Waterinfo_RWS/1955/Euro platform.csv as it contains no data records or less than 10 records.
# Finished loading observational data from Waterinfo_RWS for 8 stations.
# Loading observational data for year: 1954
# Skipping /gpfs/work3/0/ai4nbs/hurry_wave/north_sea/01_data/Waterinfo_RWS/1954/Platform Hoorn Q1-A.csv as it contains no data records or less than 10 records.
# Skipping /gpfs/work3/0/ai4nbs/hurry_wave/north_sea/01_data/Waterinfo_RWS/1954/Platform F16-A.csv as it contains no data records or less than 10 records.
# Skipping /gpfs/work3/0/ai4nbs/hurry_wave/north_sea/01_data/Waterinfo_RWS/1954/IJmuiden munitiestortplaats.csv as it contains no data records or less than 10 records.
# Skipping /gpfs/work3/0/ai4nbs/hurry_wave/north_sea/01_data/Waterinfo_RWS/1954/Platform D15-A.csv as it contains no data records or less than 10 records.
# Skipping /gpfs/work3/0/ai4nbs/hurry_wave/north_sea/01_data/Waterinfo_RWS/1954/K13a platform.csv as it contains no data records or less than 10 records.
# Skipping /gpfs/work3/0/ai4nbs/hurry_wave/north_sea/01_data/Waterinfo_RWS/1954/K13 Alpha.csv as it contains no data records or less than 10 records.
# Skipping /gpfs/work3/0/ai4nbs/hurry_wave/north_sea/01_data/Waterinfo_RWS/1954/North Cormorant.csv as it contains no data records or less than 10 records.
# Skipping /gpfs/work3/0/ai4nbs/hurry_wave/north_sea/01_data/Waterinfo_RWS/1954/Euro platform.csv as it contains no data records or less than 10 records.
# Finished loading observational data from Waterinfo_RWS for 8 stations.
# Loading observational data for year: 1953
# Skipping /gpfs/work3/0/ai4nbs/hurry_wave/north_sea/01_data/Waterinfo_RWS/1953/Platform Hoorn Q1-A.csv as it contains no data records or less than 10 records.
# Skipping /gpfs/work3/0/ai4nbs/hurry_wave/north_sea/01_data/Waterinfo_RWS/1953/Platform F16-A.csv as it contains no data records or less than 10 records.
# Skipping /gpfs/work3/0/ai4nbs/hurry_wave/north_sea/01_data/Waterinfo_RWS/1953/IJmuiden munitiestortplaats.csv as it contains no data records or less than 10 records.
# Skipping /gpfs/work3/0/ai4nbs/hurry_wave/north_sea/01_data/Waterinfo_RWS/1953/Platform D15-A.csv as it contains no data records or less than 10 records.
# Skipping /gpfs/work3/0/ai4nbs/hurry_wave/north_sea/01_data/Waterinfo_RWS/1953/K13a platform.csv as it contains no data records or less than 10 records.
# Skipping /gpfs/work3/0/ai4nbs/hurry_wave/north_sea/01_data/Waterinfo_RWS/1953/K13 Alpha.csv as it contains no data records or less than 10 records.
# Skipping /gpfs/work3/0/ai4nbs/hurry_wave/north_sea/01_data/Waterinfo_RWS/1953/North Cormorant.csv as it contains no data records or less than 10 records.
# Skipping /gpfs/work3/0/ai4nbs/hurry_wave/north_sea/01_data/Waterinfo_RWS/1953/Euro platform.csv as it contains no data records or less than 10 records.
# Finished loading observational data from Waterinfo_RWS for 8 stations.
# Loading observational data for year: 1952
# Skipping /gpfs/work3/0/ai4nbs/hurry_wave/north_sea/01_data/Waterinfo_RWS/1952/Platform Hoorn Q1-A.csv as it contains no data records or less than 10 records.
# Skipping /gpfs/work3/0/ai4nbs/hurry_wave/north_sea/01_data/Waterinfo_RWS/1952/Platform F16-A.csv as it contains no data records or less than 10 records.
# Skipping /gpfs/work3/0/ai4nbs/hurry_wave/north_sea/01_data/Waterinfo_RWS/1952/IJmuiden munitiestortplaats.csv as it contains no data records or less than 10 records.
# Skipping /gpfs/work3/0/ai4nbs/hurry_wave/north_sea/01_data/Waterinfo_RWS/1952/Platform D15-A.csv as it contains no data records or less than 10 records.
# Skipping /gpfs/work3/0/ai4nbs/hurry_wave/north_sea/01_data/Waterinfo_RWS/1952/K13a platform.csv as it contains no data records or less than 10 records.
# Skipping /gpfs/work3/0/ai4nbs/hurry_wave/north_sea/01_data/Waterinfo_RWS/1952/K13 Alpha.csv as it contains no data records or less than 10 records.
# Skipping /gpfs/work3/0/ai4nbs/hurry_wave/north_sea/01_data/Waterinfo_RWS/1952/North Cormorant.csv as it contains no data records or less than 10 records.
# Skipping /gpfs/work3/0/ai4nbs/hurry_wave/north_sea/01_data/Waterinfo_RWS/1952/Euro platform.csv as it contains no data records or less than 10 records.
# Finished loading observational data from Waterinfo_RWS for 8 stations.
# Loading observational data for year: 1951
# Skipping /gpfs/work3/0/ai4nbs/hurry_wave/north_sea/01_data/Waterinfo_RWS/1951/Platform Hoorn Q1-A.csv as it contains no data records or less than 10 records.
# Skipping /gpfs/work3/0/ai4nbs/hurry_wave/north_sea/01_data/Waterinfo_RWS/1951/Platform F16-A.csv as it contains no data records or less than 10 records.
# Skipping /gpfs/work3/0/ai4nbs/hurry_wave/north_sea/01_data/Waterinfo_RWS/1951/IJmuiden munitiestortplaats.csv as it contains no data records or less than 10 records.
# Skipping /gpfs/work3/0/ai4nbs/hurry_wave/north_sea/01_data/Waterinfo_RWS/1951/Platform D15-A.csv as it contains no data records or less than 10 records.
# Skipping /gpfs/work3/0/ai4nbs/hurry_wave/north_sea/01_data/Waterinfo_RWS/1951/K13a platform.csv as it contains no data records or less than 10 records.
# Skipping /gpfs/work3/0/ai4nbs/hurry_wave/north_sea/01_data/Waterinfo_RWS/1951/K13 Alpha.csv as it contains no data records or less than 10 records.
# Skipping /gpfs/work3/0/ai4nbs/hurry_wave/north_sea/01_data/Waterinfo_RWS/1951/North Cormorant.csv as it contains no data records or less than 10 records.
# Skipping /gpfs/work3/0/ai4nbs/hurry_wave/north_sea/01_data/Waterinfo_RWS/1951/Euro platform.csv as it contains no data records or less than 10 records.
# Finished loading observational data from Waterinfo_RWS for 8 stations.
# Loading observational data for year: 1950
# Skipping /gpfs/work3/0/ai4nbs/hurry_wave/north_sea/01_data/Waterinfo_RWS/1950/Platform Hoorn Q1-A.csv as it contains no data records or less than 10 records.
# Skipping /gpfs/work3/0/ai4nbs/hurry_wave/north_sea/01_data/Waterinfo_RWS/1950/Platform F16-A.csv as it contains no data records or less than 10 records.
# Skipping /gpfs/work3/0/ai4nbs/hurry_wave/north_sea/01_data/Waterinfo_RWS/1950/IJmuiden munitiestortplaats.csv as it contains no data records or less than 10 records.
# Skipping /gpfs/work3/0/ai4nbs/hurry_wave/north_sea/01_data/Waterinfo_RWS/1950/Platform D15-A.csv as it contains no data records or less than 10 records.
# Skipping /gpfs/work3/0/ai4nbs/hurry_wave/north_sea/01_data/Waterinfo_RWS/1950/K13a platform.csv as it contains no data records or less than 10 records.
# Skipping /gpfs/work3/0/ai4nbs/hurry_wave/north_sea/01_data/Waterinfo_RWS/1950/K13 Alpha.csv as it contains no data records or less than 10 records.
# Skipping /gpfs/work3/0/ai4nbs/hurry_wave/north_sea/01_data/Waterinfo_RWS/1950/North Cormorant.csv as it contains no data records or less than 10 records.
# Skipping /gpfs/work3/0/ai4nbs/hurry_wave/north_sea/01_data/Waterinfo_RWS/1950/Euro platform.csv as it contains no data records or less than 10 records.
# Finished loading observational data from Waterinfo_RWS for 8 stations.
# IJmuiden munitiestortplaats
# Platform D15-A
# K13a platform
# K13 Alpha
# /scratch-local/72649/ipykernel_644334/4090394968.py:64: FutureWarning: In a future version of pandas, parsing datetimes with mixed time zones will raise an error unless `utc=True`. Please specify `utc=True` to opt in to the new behaviour and silence this warning. To create a `Series` with mixed offsets and `object` dtype, please use `apply` and `datetime.datetime.strptime`
#   time_pd = pd.to_datetime(obs_data_per_station[station].pop('Unnamed: 0'))
# /scratch-local/72649/ipykernel_644334/4090394968.py:65: UserWarning: no explicit representation of timezones available for np.datetime64
#   obs_data_per_station[station]['time'] = time_pd.values.astype('datetime64[ns]')
# North Cormorant
# Euro platform
# Platform Hoorn Q1-A
# Platform F16-A

# %%
for station, df in obs_data_per_station.items():
    if 'hm0' in df and not df['hm0'].dropna().empty:
        start_time = df.loc[df['hm0'].first_valid_index(), 'time']
        end_time = df.loc[df['hm0'].last_valid_index(), 'time']
        print(f"{station}: hm0 data from {start_time} to {end_time}")
# Out:
# IJmuiden munitiestortplaats: hm0 data from 2023-01-01 00:00:00 to 1976-05-01 06:00:00
# Platform D15-A: hm0 data from 2017-01-01 00:00:00 to 2009-12-31 00:00:00
# K13a platform: hm0 data from 2023-01-01 00:00:00 to 1978-12-29 21:00:00
# K13 Alpha: hm0 data from 2022-12-31 23:50:00 to 2023-12-01 22:40:00
# North Cormorant: hm0 data from 2023-01-01 00:00:00 to 1987-12-24 23:00:00
# Euro platform: hm0 data from 2023-01-01 00:00:00 to 1982-12-31 00:00:00
# Platform Hoorn Q1-A: hm0 data from 2022-01-01 00:20:00 to 2009-12-31 00:00:00
# Platform F16-A: hm0 data from 2020-01-01 00:00:00 to 2009-12-31 00:00:00

# %%
for station, df in obs_data_per_station.items():
    if 't13' in df and not df['t13'].dropna().empty:
        start_time = df.loc[df['t13'].first_valid_index(), 'time']
        end_time = df.loc[df['t13'].last_valid_index(), 'time']
        print(f"{station}: t13 data from {start_time} to {end_time}")
# Out:
# IJmuiden munitiestortplaats: t13 data from 2023-01-01 00:00:00 to 2007-12-31 00:00:00
# Platform D15-A: t13 data from 2017-01-01 00:00:00 to 2009-12-31 00:00:00
# K13a platform: t13 data from 2023-01-01 00:00:00 to 2007-12-31 00:00:00
# K13 Alpha: t13 data from 2022-12-31 23:50:00 to 2023-12-01 22:40:00
# Euro platform: t13 data from 2023-01-01 00:00:00 to 2007-12-31 00:00:00
# Platform Hoorn Q1-A: t13 data from 2022-01-01 00:20:00 to 2009-12-31 00:00:00
# Platform F16-A: t13 data from 2020-01-01 00:00:00 to 2009-12-31 00:00:00

# %%
for station, df in obs_data_per_station.items():
    if 'th0' in df and not df['th0'].dropna().empty:
        start_time = df.loc[df['th0'].first_valid_index(), 'time']
        end_time = df.loc[df['th0'].last_valid_index(), 'time']
        print(f"{station}: th0 data from {start_time} to {end_time}")
# Out:
# IJmuiden munitiestortplaats: th0 data from 2023-01-01 00:00:00 to 1989-12-31 00:00:00
# K13a platform: th0 data from 2023-01-01 00:00:00 to 1985-12-31 00:00:00
# North Cormorant: th0 data from 1989-02-28 23:00:00 to 1987-12-24 23:00:00
# Euro platform: th0 data from 2023-01-01 00:00:00 to 1985-12-31 00:00:00
# Platform Hoorn Q1-A: th0 data from 2022-01-14 08:10:00 to 2009-12-31 00:00:00
